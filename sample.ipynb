# %% [markdown]
# # A Simple Jupyter Notebook

# %%
from matplotlib import pyplot as plt
import numpy as np

# %%
t = np.linspace(0, 10*2*np.pi, 256)
theta = np.sin(t)

# %%
plt.polar(t, t)
plt.show()
